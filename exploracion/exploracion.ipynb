# %%
import statsapi as stp

teams = stp.get('teams' , {'sportId' : 1})
print(f"Total de equipos: {len(teams['teams'])}")
print("\nPrimer equipo:")

print(teams['teams'][0])
# Out:
# Total de equipos: 30
#
# Primer equipo:
# {'springLeague': {'id': 114, 'name': 'Cactus League', 'link': '/api/v1/league/114', 'abbreviation': 'CL'}, 'allStarStatus': 'N', 'id': 133, 'name': 'Athletics', 'link': '/api/v1/teams/133', 'season': 2026, 'venue': {'id': 2529, 'name': 'Sutter Health Park', 'link': '/api/v1/venues/2529'}, 'springVenue': {'id': 2507, 'link': '/api/v1/venues/2507'}, 'teamCode': 'ath', 'fileCode': 'ath', 'abbreviation': 'ATH', 'teamName': 'Athletics', 'locationName': 'Sacramento', 'firstYearOfPlay': '1901', 'league': {'id': 103, 'name': 'American League', 'link': '/api/v1/league/103'}, 'division': {'id': 200, 'name': 'American League West', 'link': '/api/v1/divisions/200'}, 'sport': {'id': 1, 'link': '/api/v1/sports/1', 'name': 'Major League Baseball'}, 'shortName': 'Athletics', 'franchiseName': 'Athletics', 'clubName': 'Athletics', 'active': True}

# %%
roster = stp.get('team_roster', {'teamId': 136 , 'season' : 2020})
print(f"\nTotal de jugadores en el roster: {len(roster['roster'])}")
print("\nPrimer jugador en el roster:")
print(roster['roster'][0])
# Out:
# Total de jugadores en el roster: 49
#
# Primer jugador en el roster:
# {'person': {'id': 656186, 'fullName': 'Dan Altavilla', 'link': '/api/v1/people/656186'}, 'jerseyNumber': '53', 'position': {'code': '1', 'name': 'Pitcher', 'type': 'Pitcher', 'abbreviation': 'P'}, 'status': {'code': 'TR', 'description': 'Traded'}}

# %%
player = stp.get('person', {'personId' : 592450})
print(f"\nInformación del jugador: {player['people'][0]['fullName']} - Número: {player['people'][0]['primaryNumber']}")
# Out:
# Información del jugador: Aaron Judge - Número: 99

# %%
roster = stp.get('team_roster', {'teamId': 136 , 'season' : 2025})

players_info = []
for player in roster['roster']:
    player_id = player['person']['id']
    details = stp.get('person', {'personId': player_id})
    info = details['people'][0]
    
    players_info.append({
        'nombre' : info.get('fullName', 'N/A'),
        'número' : info.get('primaryNumber', 'N/A'),
        'pais' : info.get('birthCountry', 'N/A'),
        'ciudad' : info.get('birthCity', 'N/A'),
        'posicion' : player['position']['name']
    })

for p in players_info:
    print(p)
# Out:
# {'nombre': 'Randy Arozarena', 'número': '56', 'pais': 'Cuba', 'ciudad': 'Havana', 'posicion': 'Outfielder'}
# {'nombre': 'Eduard Bazardo', 'número': '83', 'pais': 'Venezuela', 'ciudad': 'Maracay', 'posicion': 'Pitcher'}
# {'nombre': 'Ryan Bliss', 'número': '1', 'pais': 'USA', 'ciudad': 'Burbank', 'posicion': 'Second Base'}
# {'nombre': 'Matt Brash', 'número': '47', 'pais': 'Canada', 'ciudad': 'Kingston', 'posicion': 'Pitcher'}
# {'nombre': 'Juan Burgos', 'número': '52', 'pais': 'Dominican Republic', 'ciudad': 'Santiago', 'posicion': 'Pitcher'}
# {'nombre': 'Dominic Canzone', 'número': '8', 'pais': 'USA', 'ciudad': 'Cleveland', 'posicion': 'Outfielder'}
# {'nombre': 'Blas Castaño', 'número': '63', 'pais': 'Dominican Republic', 'ciudad': 'Espaillat', 'posicion': 'Pitcher'}
# {'nombre': 'José Castillo', 'número': 'N/A', 'pais': 'Venezuela', 'ciudad': 'Valencia', 'posicion': 'Pitcher'}
# {'nombre': 'Luis Castillo', 'número': '58', 'pais': 'Dominican Republic', 'ciudad': 'Bani', 'posicion': 'Pitcher'}
# {'nombre': 'Luis F. Castillo', 'número': 'N/A', 'pais': 'Dominican Republic', 'ciudad': 'Fantino', 'posicion': 'Pitcher'}
# {'nombre': 'J.P. Crawford', 'número': '3', 'pais': 'USA', 'ciudad': 'Long Beach', 'posicion': 'Shortstop'}
# {'nombre': 'Jhonathan Díaz', 'número': 'N/A', 'pais': 'Venezuela', 'ciudad': 'Valencia', 'posicion': 'Pitcher'}
# {'nombre': 'Logan Evans', 'número': '23', 'pais': 'USA', 'ciudad': 'Ann Arbor', 'posicion': 'Pitcher'}
# {'nombre': 'Caleb Ferguson', 'número': '46', 'pais': 'USA', 'ciudad': 'Columbus', 'posicion': 'Pitcher'}
# {'nombre': 'Harry Ford', 'número': '17', 'pais': 'USA', 'ciudad': 'Atlanta', 'posicion': 'Catcher'}
# {'nombre': 'Brandyn Garcia', 'número': '55', 'pais': 'USA', 'ciudad': 'Newport', 'posicion': 'Pitcher'}
# {'nombre': 'Mitch Garver', 'número': '18', 'pais': 'USA', 'ciudad': 'Albuquerque', 'posicion': 'Catcher'}
# {'nombre': 'Logan Gilbert', 'número': '36', 'pais': 'USA', 'ciudad': 'Winter Park', 'posicion': 'Pitcher'}
# {'nombre': 'Jesse Hahn', 'número': '37', 'pais': 'USA', 'ciudad': 'Norwich', 'posicion': 'Pitcher'}
# {'nombre': 'Emerson Hancock', 'número': '26', 'pais': 'USA', 'ciudad': 'Cairo', 'posicion': 'Pitcher'}
# {'nombre': 'Luke Jackson', 'número': '53', 'pais': 'USA', 'ciudad': 'Fort Lauderdale', 'posicion': 'Pitcher'}
# {'nombre': 'George Kirby', 'número': '68', 'pais': 'USA', 'ciudad': 'Rye', 'posicion': 'Pitcher'}
# {'nombre': 'Jackson Kowar', 'número': '57', 'pais': 'USA', 'ciudad': 'Weddington', 'posicion': 'Pitcher'}
# {'nombre': 'Sauryn Lao', 'número': '73', 'pais': 'Dominican Republic', 'ciudad': 'Barahona', 'posicion': 'Pitcher'}
# {'nombre': 'Casey Lawrence', 'número': '41', 'pais': 'USA', 'ciudad': 'McSherrystown', 'posicion': 'Pitcher'}
# {'nombre': 'Casey Legumina', 'número': '67', 'pais': 'USA', 'ciudad': 'Dallas', 'posicion': 'Pitcher'}
# {'nombre': 'Miles Mastrobuoni', 'número': '21', 'pais': 'USA', 'ciudad': 'San Ramon', 'posicion': 'Third Base'}
# {'nombre': 'Bryce Miller', 'número': '50', 'pais': 'USA', 'ciudad': 'Mount Pleasant', 'posicion': 'Pitcher'}
# {'nombre': 'Dylan Moore', 'número': '25', 'pais': 'USA', 'ciudad': 'Yorba Linda', 'posicion': 'Second Base'}
# {'nombre': 'Andrés Muñoz', 'número': '75', 'pais': 'Mexico', 'ciudad': 'Los Mochis', 'posicion': 'Pitcher'}
# {'nombre': 'Josh Naylor', 'número': '12', 'pais': 'Canada', 'ciudad': 'Mississauga', 'posicion': 'First Base'}
# {'nombre': 'Jorge Polanco', 'número': '11', 'pais': 'Dominican Republic', 'ciudad': 'San Pedro de Macoris', 'posicion': 'Second Base'}
# {'nombre': 'Zach Pop', 'número': 'N/A', 'pais': 'Canada', 'ciudad': 'Brampton', 'posicion': 'Pitcher'}
# {'nombre': 'Cal Raleigh', 'número': '29', 'pais': 'USA', 'ciudad': 'Harrisonburg', 'posicion': 'Catcher'}
# {'nombre': 'Luke Raley', 'número': '20', 'pais': 'USA', 'ciudad': 'Hinckley', 'posicion': 'Outfielder'}
# {'nombre': 'Leo Rivas', 'número': '76', 'pais': 'Venezuela', 'ciudad': 'Maracay', 'posicion': 'Second Base'}
# {'nombre': 'Victor Robles', 'número': '10', 'pais': 'Dominican Republic', 'ciudad': 'Santo Domingo Este', 'posicion': 'Outfielder'}
# {'nombre': 'Julio Rodríguez', 'número': '44', 'pais': 'Dominican Republic', 'ciudad': 'Loma de Cabrera', 'posicion': 'Outfielder'}
# {'nombre': 'Gregory Santos', 'número': '57', 'pais': 'Dominican Republic', 'ciudad': 'San Cristobal', 'posicion': 'Pitcher'}
# {'nombre': 'Tayler Saucedo', 'número': '55', 'pais': 'USA', 'ciudad': 'Honolulu', 'posicion': 'Pitcher'}
# {'nombre': 'Collin Snider', 'número': '52', 'pais': 'USA', 'ciudad': 'Nashville', 'posicion': 'Pitcher'}
# {'nombre': 'Donovan Solano', 'número': '16', 'pais': 'Colombia', 'ciudad': 'Barranquilla', 'posicion': 'First Base'}
# {'nombre': 'Gabe Speier', 'número': '55', 'pais': 'USA', 'ciudad': 'Santa Barbara', 'posicion': 'Pitcher'}
# {'nombre': 'Eugenio Suárez', 'número': '28', 'pais': 'Venezuela', 'ciudad': 'Puerto Ordaz', 'posicion': 'Third Base'}
# {'nombre': 'Leody Taveras', 'número': '30', 'pais': 'Dominican Republic', 'ciudad': 'Tenares', 'posicion': 'Outfielder'}
# {'nombre': 'Samad Taylor', 'número': '0', 'pais': 'USA', 'ciudad': 'Corona', 'posicion': 'Second Base'}
# {'nombre': 'Troy Taylor', 'número': '59', 'pais': 'USA', 'ciudad': 'Fontana', 'posicion': 'Pitcher'}
# {'nombre': 'Rowdy Tellez', 'número': '11', 'pais': 'USA', 'ciudad': 'Sacramento', 'posicion': 'First Base'}
# {'nombre': 'Rhylan Thomas', 'número': 'N/A', 'pais': 'USA', 'ciudad': 'Ventura', 'posicion': 'Outfielder'}
# {'nombre': 'Trent Thornton', 'número': '49', 'pais': 'USA', 'ciudad': 'Charlotte', 'posicion': 'Pitcher'}
# {'nombre': 'Carlos Vargas', 'número': '54', 'pais': 'Dominican Republic', 'ciudad': 'Moca', 'posicion': 'Pitcher'}
# {'nombre': 'Ben Williamson', 'número': '15', 'pais': 'USA', 'ciudad': 'Fairfax', 'posicion': 'Third Base'}
# {'nombre': 'Bryan Woo', 'número': '22', 'pais': 'USA', 'ciudad': 'Oakland', 'posicion': 'Pitcher'}
# {'nombre': 'Cole Young', 'número': '2', 'pais': 'USA', 'ciudad': 'Pittsburgh', 'posicion': 'Second Base'}

# %%
teams = stp.get('teams' , {'sportId' : 1})

team_ids = []
for team in teams['teams']:
    team_ids.append({
        
        'id' : team['id'],
        'name' : team['name']
        
    })

for t in team_ids:
    print(t)
# Out:
# {'id': 133, 'name': 'Athletics'}
# {'id': 134, 'name': 'Pittsburgh Pirates'}
# {'id': 135, 'name': 'San Diego Padres'}
# {'id': 136, 'name': 'Seattle Mariners'}
# {'id': 137, 'name': 'San Francisco Giants'}
# {'id': 138, 'name': 'St. Louis Cardinals'}
# {'id': 139, 'name': 'Tampa Bay Rays'}
# {'id': 140, 'name': 'Texas Rangers'}
# {'id': 141, 'name': 'Toronto Blue Jays'}
# {'id': 142, 'name': 'Minnesota Twins'}
# {'id': 143, 'name': 'Philadelphia Phillies'}
# {'id': 144, 'name': 'Atlanta Braves'}
# {'id': 145, 'name': 'Chicago White Sox'}
# {'id': 146, 'name': 'Miami Marlins'}
# {'id': 147, 'name': 'New York Yankees'}
# {'id': 158, 'name': 'Milwaukee Brewers'}
# {'id': 108, 'name': 'Los Angeles Angels'}
# {'id': 109, 'name': 'Arizona Diamondbacks'}
# {'id': 110, 'name': 'Baltimore Orioles'}
# {'id': 111, 'name': 'Boston Red Sox'}
# {'id': 112, 'name': 'Chicago Cubs'}
# {'id': 113, 'name': 'Cincinnati Reds'}
# {'id': 114, 'name': 'Cleveland Guardians'}
# {'id': 115, 'name': 'Colorado Rockies'}
# {'id': 116, 'name': 'Detroit Tigers'}
# {'id': 117, 'name': 'Houston Astros'}
# {'id': 118, 'name': 'Kansas City Royals'}
# {'id': 119, 'name': 'Los Angeles Dodgers'}
# {'id': 120, 'name': 'Washington Nationals'}
# {'id': 121, 'name': 'New York Mets'}

# %%
import sqlite3 as sql

conexion = sql.connect('mlb_nacionalidades.db')
cursor = conexion.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS jugadores (
    player_id INTEGER PRIMARY KEY,
    nombre TEXT,
    pais_nacimiento TEXT,
    ciudad_nacimiento TEXT,
    anio_debut INTEGER,
    equipo_id INTEGER,
    equipo_nombre TEXT,
    posicion TEXT,
    activo BOOLEAN,
    fecha_actualizacion TEXT
)
''')

cursor.execute('''
CREATE TABLE IF NOT EXISTS historial_diario (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    fecha TEXT,
    pais_nacimiento TEXT,
    cantidad_jugadores INTEGER
)
''')

conexion.commit()
conexion.close()

print("Base de datos creada y tablas creadas")
# Out:
# Base de datos creada y tablas creadas

# %%
import time

teams = stp.get('teams' , {'sportId' : 1})

all_players = []

for team in teams['teams']:
    team_id = team['id']
    team_name = team['name']
    
    roster = stp.get('team_roster' , {'teamId' : team_id, 'season' : 2026})
    
    for player in roster['roster']:
        player_id = player['person']['id']
        details = stp.get('person' , {'personId':player_id})
        info = details['people'][0]
        
        anio_debut = None
        if info.get('mlbDebutDate'):
            anio_debut = int(info['mlbDebutDate'][:4])
        
        all_players.append({
            'player_id': player_id,
            'nombre': info.get('fullName'),
            'pais_nacimiento': info.get('birthCountry'),
            'ciudad_nacimiento': info.get('birthCity'),
            'anio_debut': anio_debut,
            'equipo_id': team_id,
            'equipo_nombre': team_name,
            'posicion': player['position']['name'],
            'activo': info.get('active')
            
            
        })
        
        print(f"{team_name}: {len(roster['roster'])} jugadores procesados")

print(f"\nTotal de jugadores recolectados: {len(all_players)}")
# Out:
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Athletics: 25 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# Pittsburgh Pirates: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# San Diego Padres: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# Seattle Mariners: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# San Francisco Giants: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# St. Louis Cardinals: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Tampa Bay Rays: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Texas Rangers: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Toronto Blue Jays: 26 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Minnesota Twins: 25 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Philadelphia Phillies: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Atlanta Braves: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Chicago White Sox: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# Miami Marlins: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# New York Yankees: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Milwaukee Brewers: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Los Angeles Angels: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Arizona Diamondbacks: 26 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Baltimore Orioles: 25 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Boston Red Sox: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Chicago Cubs: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cincinnati Reds: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Cleveland Guardians: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Colorado Rockies: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Detroit Tigers: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Houston Astros: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Kansas City Royals: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Los Angeles Dodgers: 26 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# Washington Nationals: 25 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
# New York Mets: 26 jugadores procesados
#
# Total de jugadores recolectados: 776

# %%
from datetime import date as dt

conexion = sql.connect('mlb_nacionalidades.db')
cursor = conexion.cursor()

hoy = dt.today().isoformat()

for p in all_players:
    cursor.execute('''
        INSERT OR REPLACE INTO jugadores 
        (player_id, nombre, pais_nacimiento, ciudad_nacimiento, anio_debut, 
         equipo_id, equipo_nombre, posicion, activo, fecha_actualizacion)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (
        p['player_id'], p['nombre'], p['pais_nacimiento'], p['ciudad_nacimiento'],
        p['anio_debut'], p['equipo_id'], p['equipo_nombre'], p['posicion'],
        p['activo'], hoy
    ))

conexion.commit()
conexion.close()

print(f"{len(all_players)} jugadores guardados/actualizados en BD.")
# Out:
# 776 jugadores guardados/actualizados en BD.

# %%
conexion = sql.connect('mlb_nacionalidades.db')
cursor = conexion.cursor()

cursor.execute('Select count(*) from jugadores')
print(f"Total de jugadores en la tabla: {cursor.fetchone()[0]}")

cursor.execute('Select * from jugadores limit 3')
for fila in cursor.fetchall():
    print(fila)
conexion.close()
# Out:
# Total de jugadores en la tabla: 777
# (445276, 'Kenley Jansen', 'Curacao', 'Willemstad', 2010, 116, 'Detroit Tigers', 'Pitcher', 1, '2026-07-06')
# (455119, 'Chris Martin', 'USA', 'Arlington', 2014, 140, 'Texas Rangers', 'Pitcher', 1, '2026-07-06')
# (489446, 'Kirby Yates', 'USA', 'Lihue', 2014, 108, 'Los Angeles Angels', 'Pitcher', 1, '2026-07-06')

# %%
from collections import Counter

count_countries = Counter(p['pais_nacimiento'] for p in all_players)

conexion = sql.connect('mlb_nacionalidades.db')
cursor = conexion.cursor()

for country, count in count_countries.items():
    cursor.execute(''' 
        
        insert into historial_diario (fecha , pais_nacimiento, cantidad_jugadores)
        values(?,?,?)        
                   
            ''',(hoy, country, count))

conexion.commit()
conexion.close()

print(f"Historial guardado para {len(count_countries)} paises, fecha {hoy}")
# Out:
# Historial guardado para 23 paises, fecha 2026-07-06

# %%
conexion = sql.connect('mlb_nacionalidades.db')
cursor = conexion.cursor()

cursor.execute('select * from historial_diario order by cantidad_jugadores desc limit 10')
for f in cursor.fetchall():
    print(f)
conexion.close()
# Out:
# (1, '2026-07-06', 'USA', 576)
# (2, '2026-07-06', 'Dominican Republic', 67)
# (3, '2026-07-06', 'Venezuela', 49)
# (4, '2026-07-06', 'Cuba', 15)
# (9, '2026-07-06', 'Canada', 12)
# (10, '2026-07-06', 'Puerto Rico', 11)
# (7, '2026-07-06', 'Japan', 10)
# (8, '2026-07-06', 'Mexico', 9)
# (11, '2026-07-06', 'Panama', 6)
# (14, '2026-07-06', 'Colombia', 3)

# %%
def obtain_team_players(team_id, team_name):

    team_players = []
    
    roster = stp.get('team_roster' , {'teamId' : team_id , 'season' : '2026'})
    
    for player in roster['roster']:
        player_id = player['person']['id']
        details = stp.get('person' , {'personId' : player_id})
        info = details['people'][0]
        
        anio_debut = None
        if info.get('mlbDebutDate'):
            anio_debut = int(info['mlbDebutDate'][:4])
        
        team_players.append({
            'player_id': player_id,
            'nombre': info.get('fullName'),
            'pais_nacimiento': info.get('birthCountry'),
            'ciudad_nacimiento': info.get('birthCity'),
            'anio_debut': anio_debut,
            'equipo_id': team_id,
            'equipo_nombre': team_name,
            'posicion': player['position']['name'],
            'activo': info.get('active')
            
            
        })
    return team_players

def obtain_teams():
    
    teams = stp.get('teams' , {'sportId' : 1})
    
    return teams['teams']

def save_players(players):
    
    conexion = sql.connect('mlb_nacionalidades.db')
    cursor = conexion.cursor()

    

    for p in players:
        cursor.execute('''
            INSERT OR REPLACE INTO jugadores 
            (player_id, nombre, pais_nacimiento, ciudad_nacimiento, anio_debut, 
            equipo_id, equipo_nombre, posicion, activo, fecha_actualizacion)
            VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
        ''', (
            p['player_id'], p['nombre'], p['pais_nacimiento'], p['ciudad_nacimiento'],
            p['anio_debut'], p['equipo_id'], p['equipo_nombre'], p['posicion'],
            p['activo'], hoy
        ))

    conexion.commit()
    conexion.close()
    print(f"{len(players)} jugadores guardados/actualizados")

def save_history(players):
    count_countries = Counter(p['pais_nacimiento'] for p in players)

    conexion = sql.connect('mlb_nacionalidades.db')
    cursor = conexion.cursor()

    cursor.execute('delete from historial_diario where fecha = ?', (hoy,))
    
    for country, count in count_countries.items():
        cursor.execute(''' 
            
            insert into historial_diario (fecha , pais_nacimiento, cantidad_jugadores)
            values(?,?,?)        
                    
                ''',(hoy, country, count))

    conexion.commit()
    conexion.close()

    print(f"Historial guardado para {len(count_countries)} paises, fecha {hoy}")

def main():
    print("Iniciando extracción diaria...")
    
    teams = obtain_teams()
    print(f"Equipos encontrados: {len(teams)}")
    
    all_players = []
    for team in teams:
        team_players = obtain_team_players(team['id'] ,  team['name'])
        all_players.extend(team_players)
    print(f"\nTotal recolectado: {len(all_players)} jugadores")
    save_players(all_players)
    save_history(all_players)
    
    print("Proceso completado.")

# %%
prueba = obtain_team_players(136, 'Seattle Mariners')
print(f"Jugadores obtenidos: {len(prueba)}")
print(prueba[0])
# Out:
# Jugadores obtenidos: 26
# {'player_id': 662253, 'nombre': 'Andrés Muñoz', 'pais_nacimiento': 'Mexico', 'ciudad_nacimiento': 'Los Mochis', 'anio_debut': 2019, 'equipo_id': 136, 'equipo_nombre': 'Seattle Mariners', 'posicion': 'Pitcher', 'activo': True}

# %%
main()
# Out:
# Iniciando extracción diaria...
# Equipos encontrados: 30
#
# Total recolectado: 776 jugadores
# 776 jugadores guardados/actualizados
# Historial guardado para 23 paises, fecha 2026-07-06
# Proceso completado.

# %%
conexion = sql.connect('mlb_nacionalidades.db')
cursor = conexion.cursor()

cursor.execute('select fecha , count(*) from historial_diario group by fecha')
print(cursor.fetchall())

conexion.close()
# Out:
# [('2026-07-06', 23)]

# %%
conexion = sql.connect('mlb_nacionalidades.db')
cursor = conexion.cursor()

cursor.execute("delete from historial_diario where fecha ='2026-07-06' ")
conexion.commit()

cursor.execute('select fecha , count(*) from historial_diario group by fecha')
print(cursor.fetchall())

conexion.close()
# Out:
# []
